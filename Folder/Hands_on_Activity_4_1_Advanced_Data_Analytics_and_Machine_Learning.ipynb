# %% [markdown]
# | <h1> Activity 4.1 </h1> | <h1> Advanced Data Analytics and Machine Learning </h1> |
# |--- | --- |
# Name: Gullas, Rainer L.<br>
# Course and Section: CPE019S3 <br>
# Date Submitted: 02/21/2024<br>
# Instructor: Engr. Roman Richard
# Date Performed: 02/21/2024
# Date Submitted: 02/21/2024

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd

# %%
#Import pandas and the csv file
training = pd.read_csv("/content/titanic_train.csv")

# %%
#Verify the import and take a look at the data.
training.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
print(training.iloc[0])
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %% [markdown]
# <h1>There are missing values in the Age, Cabin, and Embarked Sections</h1>

# %%
#Prepare the Data for the Decision Tree Model.
training["Sex"] = training["Sex"].apply(lambda toLabel: 0 if toLabel ==
'male' else 1)

# %%
training.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
training["Age"].fillna(training["Age"].mean(), inplace=True)

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
#Train and Score the Decision Tree Model.
y_target = training["Survived"].values

# %%
columns = ["Fare", "Pclass", "Sex", "Age", "SibSp"]

X_input = training[list(columns)].values

# %%
from sklearn import tree

# %%
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

clf_train = clf_train.fit(X_input, y_target)

# %%
clf_train.score(X_input,y_target)
# Out:
# 0.8226711560044894

# %%
import slx
import sys
sys.module['sklearn.externals.six']
with open("titanic.dot", 'w') as f:
  f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-97-b29566d886f2> in <cell line: 1>()
# ----> 1 import slx
#       2 import sys
#       3 sys.module['sklearn.externals.six']
#
# ModuleNotFoundError: No module named 'slx'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Visualize the Tree
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-95-27c0038db8d9> in <cell line: 3>()
#       1 #Visualize the Tree
#       2 from six import StringIO
# ----> 3 with open("./Data/titanic.dot", 'w') as f:
#       4   f = tree.export_graphviz(clf_train, out_file=f, feature_names=columns)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data/titanic.dot'

# %%
# !apt install libgraphviz-dev
# !pip install pygraphviz

# %%
# !dot -Tpng ./Data/titanic.dot -o ./Data/titanic.png
# Out:
# Error: dot: can't open ./Data/titanic.dot

# %% [markdown]
# <h1>Based on the tree the most deaths are male at the age of 13.5 and that paid less in the fare, while the most survivors are females who were at the first and second class</h1>

# %%
testing = pd.read_csv("/content/titanic_test.csv")

# %% [markdown]
# How many records are in the data set?
#
# ***393***
#
# Which important variables(s) are missing values and how many are missing?
#
# ***86 values are missing***

# %%
testing.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
testing["Sex"] = testing["Sex"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
testing.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
testing["Age"].fillna(testing["Age"].mean(), inplace=True)

# %%
testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    int64
#  4   Age          418 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.0+ KB

# %%
testing.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    1
# 2          894       2                     Myles, Mr. Thomas Francis    0
# 3          895       3                              Wirz, Mr. Albert    0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
X_input = testing[list(columns)].values

# %%
target_labels = clf_train.predict(X_input)

#convert the target array into a pandas dataframe using the pd.DataFrame() method and target as argument
target_labels = pd.DataFrame({'Est_Survival':target_labels, 'Name':testing['Name']})

#display the first few rows of the data set
# SOLUTION:
target_labels.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-96153c38309d> in <cell line: 1>()
# ----> 1 target.labels = clf_train.predict(X_input)
#       2
#       3 #convert the target array into a pandas dataframe using the pd.DataFrame() method and target as argument
#       4 target.labels = pd.DataFrame({'Est_Survival':target.labels, 'Name':testing['Name']})
#       5
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     424         """
#     425         check_is_fitted(self)
# --> 426         X = self._validate_X_predict(X, check_input)
#     427         proba = self.tree_.predict(X)
#     428         n_samples = X.shape[0]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
# ...

# %%
from google.colab import files
files.upload()

# %%
import numpy as np
# Load data for all passengers in the variable all_data
all_data = pd.read_csv("/content/titanic_dataset.csv")
# Merging using the field Name as key, selects only the rows of the two datasets that refer to the same passenger
testing_results = pd.merge(target_labels, all_data[['Name','Survived']], on=['Name'])
# Compute the accuracy as a ratio of matching observations to total osbervations. Store this in in the variable acc.
acc = np.sum(testing_results['Est_Survival'] == testing_results['Survived']) / float(len(testing_results))
# Print the result
print(acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-82030bbdb558> in <cell line: 5>()
#       3 all_data = pd.read_csv("/content/titanic_dataset.csv")
#       4 # Merging using the field Name as key, selects only the rows of the two datasets that refer to the same passenger
# ----> 5 testing_results = pd.merge(target_labels, all_data[['Name','Survived']], on=[
#       6 'Name'])
#       7 # Compute the accuracy as a ratio of matching observations to total osbervations. Store this in in the variable acc.
#
# NameError: name 'target_labels' is not defined

# %% [markdown]
# How many records are in the data set?
#
# ***1308***
#
# Which important variables(s) are missing values and how many are missing?
#
# ***263***

# %%
all_data = pd.read_csv("/content/titanic_dataset.csv", usecols=['Survived','Pclass',
'Sex','Age','SibSp','Fare'])

all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Fare      891 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 41.9+ KB

# %%
all_data["Sex"] = all_data["Sex"].apply(lambda toLabel: 0 if toLabel == 'male' else 1)

# %%
all_data["Age"].fillna(all_data["Age"].mean(), inplace=True)

all_data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp     Fare
# 0         0       3    0  22.0      1   7.2500
# 1         1       1    1  38.0      1  71.2833
# 2         1       3    1  26.0      0   7.9250
# 3         1       1    1  35.0      1  53.1000
# 4         0       3    0  35.0      0   8.0500

# %%
from sklearn.model_selection import train_test_split

#create the input and target variables as uppercase X and lowercase y. Reuse the columns variable.
X = all_data[list(columns)].values
y = all_data["Survived"].values

#generate the four testing and training data arrays with the train_test_split() method
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.40, random_state=0)

# %%
clf_train = tree.DecisionTreeClassifier(criterion="entropy", max_depth=3)

#fit the training model using the input and target variables
clf_train = clf_train.fit(X_train, y_train)

# %%
train_score = str(clf_train.score(X_train,y_train))
test_score = str(clf_train.score(X_test,y_test))

#output the values in a test string
print('Training score = '+ train_score+' Testing score = '+test_score)
# Out:
# Training score = 0.8277153558052435 Testing score = 0.803921568627451
